# %% [markdown]
# Hello world

# %%
import pandas as pd

# %%
# save filepath to variable for easier access
game_players_stats_path = '../data/game_players_stats.csv'
# read the data and store data in DataFrame titled melbourne_data
game_players_stats_data = pd.read_csv(game_players_stats_path) 
# print a summary of the data in Melbourne data
game_players_stats_data.describe()
# Out:
#              game_id      player_id        team_id   game_length  \
# count  374554.000000  374554.000000  374554.000000  3.745540e+05
# mean    18729.401448    1549.469631     283.521236  2.376872e+03
# std     10813.836519    1234.016945     222.844447  3.202794e+04
# min         0.000000       0.000000       0.000000  8.060000e+02
# 25%      9363.000000     480.000000      86.000000  1.682000e+03
# 50%     18731.000000    1221.000000     221.000000  1.873000e+03
# 75%     28094.000000    2409.000000     449.000000  2.111000e+03
# max     37458.000000    4952.000000     843.000000  2.793607e+06
#
#           team_kills    tower_kills  inhibitor_kills   dragon_kills  \
# count  374554.000000  374554.000000    374554.000000  374554.000000
# mean       13.915163       6.018486         0.895227       2.262723
# std         7.267931       3.618850         1.065168       1.400929
# min         0.000000       0.000000         0.000000       0.000000
# ...

# %%
game_players_stats_data.head()
# Out:
#    game_id  player_id player_name  team_id               team_name  \
# 0       15          0      shanji        0    Legend Esport Gaming
# 1       15          1       Demon        1  Bilibili Gaming Junior
# 2       15          2     yanxuan        0    Legend Esport Gaming
# 3       15          3        Viod        0    Legend Esport Gaming
# 4       15          4     HanXuan        1  Bilibili Gaming Junior
#
#   team_acronym     role    win  game_length champion_name  ...  \
# 0          LEG      Top  False         1415        Irelia  ...
# 1         BLGJ      Top   True         1415      Vladimir  ...
# 2          LEG      Bot  False         1415        Kai'Sa  ...
# 3          LEG  Support  False         1415           Lux  ...
# 4         BLGJ      Mid   True         1415        Aatrox  ...
#
#    player_assists  total_minions_killed  gold_earned  level  \
# 0               1                   179         8530     12
# ...

# %%
game_players_stats_data.isna().sum()
# Out:
# game_id                              0
# player_id                            0
# player_name                          0
# team_id                              0
# team_name                            0
# team_acronym                       290
# role                                 0
# win                                  0
# game_length                          0
# champion_name                        0
# team_kills                           0
# tower_kills                          0
# inhibitor_kills                      0
# dragon_kills                         0
# herald_kills                         0
# baron_kills                          0
# player_kills                         0
# player_deaths                        0
# player_assists                       0
# total_minions_killed                 0
# gold_earned                          0
# level                                0
# total_damage_dealt                   0
# total_damage_dealt_to_champions      0
# ...

# %%
import numpy as np
# Filtrer les ADC
df_adc = game_players_stats_data[game_players_stats_data['role'] == 'Bot'].copy()

# Calculer les features dérivées
df_adc['KDA'] = (df_adc['player_kills'] + df_adc['player_assists']) / np.maximum(df_adc['player_deaths'], 1)
df_adc['gold_per_min'] = df_adc['gold_earned'] / (df_adc['game_length'] / 60)
df_adc['cs_per_min'] = df_adc['total_minions_killed'] / (df_adc['game_length'] / 60)

# Sélection des features finales
features = [
    'gold_per_min', 'cs_per_min', 'KDA', 
    'total_damage_dealt_to_champions', 'largest_killing_spree',
    'wards_placed'
]
X = df_adc[features]
y = df_adc['win'].astype(int)  # Target: 1 pour victoire, 0 pour défaite
# Out:
# Valeurs uniques de y : [0 1]
# Valeurs manquantes dans y : 0

# %%
mask_anormal = (
    (df_adc['gold_per_min'] <= 100) |
    (df_adc['cs_per_min'] <= 1) |
    (df_adc['total_damage_dealt_to_champions'] <= 1000)
)
df_adc_anormal = df_adc[mask_anormal]
print(f"Nombre de lignes suspectes : {len(df_adc_anormal)}")
pd.set_option('display.max_columns', None)

df_adc_anormal.head(10)  # Affiche les 10 premières
# Out:
# Nombre de lignes suspectes : 154
#        game_id  player_id player_name  team_id                      team_name  \
# 2496       279        427        5Kid       77                          Asura
# 9152      2041        472        Wink       85                   eStar Gaming
# 10653     1080        265       Viper       51                        Griffin
# 12652     1919        570      Blazes       49                    GAM Esports
# 13199     1502        681      Venzer      129  Unicorns Of Love Sexy Edition
# 14522     2036       1171   JamesPeke      198                  Vega Squadron
# 14714     2159        737     Rafitta      140              UCAM Esports Club
# 14933      387        360          y4       66                   Victory Five
# 17834     1714        991   KreshtDoo      182                 Azules Esports
# 20089     1965        582     BigKoro      109                 Saigon Buffalo
#
#       team_acronym role    win  game_length champion_name  team_kills  \
# ...
